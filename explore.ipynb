# %% [markdown]
# <h2>Initial Exploration of Wikipedia Pageview Data<h2>

# %%
import pandas as pd
import sqlite3
import plotly.express as px

# %%
conn = sqlite3.connect('raw_data.db')

sql_query = "SELECT * FROM pageviews"
df = pd.read_sql_query(sql_query, conn)

# %% [markdown]
# <h3>Filter out irrelevant search_keys and dates outside of 2024

# %%
df = df[~df['search_key'].isin(['Cookie_(informatique)', 'Main_Page'])]
df = df[df['date'].str[:4] == '2024']

# %% [markdown]
# <h3>Beginning of data (Jan 1, 2024)

# %%
df.head(10).style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_321b2">
#   <thead>
#     <tr>
#       <th id="T_321b2_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_321b2_level0_col1" class="col_heading level0 col1" >search_id</th>
#       <th id="T_321b2_level0_col2" class="col_heading level0 col2" >search_key</th>
#       <th id="T_321b2_level0_col3" class="col_heading level0 col3" >view_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_321b2_row0_col0" class="data row0 col0" >2024-01-01</td>
#       <td id="T_321b2_row0_col1" class="data row0 col1" >18713</td>
#       <td id="T_321b2_row0_col2" class="data row0 col2" >Lynyrd_Skynyrd</td>
#       <td id="T_321b2_row0_col3" class="data row0 col3" >374849</td>
#     </tr>
#     <tr>
#       <td id="T_321b2_row1_col0" class="data row1 col0" >2024-01-01</td>
#       <td id="T_321b2_row1_col1" class="data row1 col1" >36792343</td>
#       <td id="T_321b2_row1_col2" class="data row1 col2" >Elle_King</td>
#       <td id="T_321b2_row1_col3" class="data row1 col3" >307689</td>
#     </tr>
#     <tr>
#       <td id="T_321b2_row2_col0" class="data row2 col0" >2024-01-01</td>
#       <td id="T_321b2_row2_col1" class="data row2 col1" >100691</td>
#       <td id="T_321b2_row2_col2" class="data row2 col2" >Paul_Anka</td>
#       <td id="T_321b2_row2_col3" class="data row2 col3" >269259</td>
#     </tr>
#     <tr>
#       <td id="T_321b2_row3_col0" class="data row3 col0" >2024-01-01</td>
#       <td id="T_321b2_row3_col1" class="data row3 col1" >80903</td>
#       <td id="T_321b2_row3_col2" class="data row3 col2" >Billie_Joe_Armstrong</td>
#       <td id="T_321b2_row3_col3" class="data row3 col3" >191331</td>
#     </tr>
#     <tr>
#       <td id="T_321b2_row4_col0" class="data row4 col0" >2024-01-01</td>
#       <td id="T_321b2_row4_col1" class="data row4 col1" >52726</td>
#       <td id="T_321b2_row4_col2" class="data row4 col2" >Green_Day</td>
#       <td id="T_321b2_row4_col3" class="data row4 col3" >170677</td>
#     </tr>
#     <tr>
#       <td id="T_321b2_row5_col0" class="data row5 col0" >2024-01-01</td>
#       <td id="T_321b2_row5_col1" class="data row5 col1" >54162498</td>
#       <td id="T_321b2_row5_col2" class="data row5 col2" >Gypsy_Rose_Blanchard</td>
#       <td id="T_321b2_row5_col3" class="data row5 col3" >164705</td>
#     </tr>
#     <tr>
#       <td id="T_321b2_row6_col0" class="data row6 col0" >2024-01-01</td>
#       <td id="T_321b2_row6_col1" class="data row6 col1" >170459</td>
#       <td id="T_321b2_row6_col2" class="data row6 col2" >LL_Cool_J</td>
#       <td id="T_321b2_row6_col3" class="data row6 col3" >162843</td>
#     </tr>
#     <tr>
#       <td id="T_321b2_row7_col0" class="data row7 col0" >2024-01-01</td>
#       <td id="T_321b2_row7_col1" class="data row7 col1" >218238</td>
#       <td id="T_321b2_row7_col2" class="data row7 col2" >Rob_Schneider</td>
#       <td id="T_321b2_row7_col3" class="data row7 col3" >150123</td>
#     </tr>
#     <tr>
#       <td id="T_321b2_row8_col0" class="data row8 col0" >2024-01-01</td>
#       <td id="T_321b2_row8_col1" class="data row8 col1" >1473365</td>
#       <td id="T_321b2_row8_col2" class="data row8 col2" >Johnny_Van_Zant</td>
#       <td id="T_321b2_row8_col3" class="data row8 col3" >140385</td>
#     </tr>
#     <tr>
#       <td id="T_321b2_row9_col0" class="data row9 col0" >2024-01-01</td>
#       <td id="T_321b2_row9_col1" class="data row9 col1" >12342282</td>
#       <td id="T_321b2_row9_col2" class="data row9 col2" >List_of_Lynyrd_Skynyrd_members</td>
#       <td id="T_321b2_row9_col3" class="data row9 col3" >132688</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <h3>Pages with most views in a single day in 2024

# %%
df.sort_values(by='view_count', ascending=False).head(10).style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_3738b">
#   <thead>
#     <tr>
#       <th id="T_3738b_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_3738b_level0_col1" class="col_heading level0 col1" >search_id</th>
#       <th id="T_3738b_level0_col2" class="col_heading level0 col2" >search_key</th>
#       <th id="T_3738b_level0_col3" class="col_heading level0 col3" >view_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3738b_row0_col0" class="data row0 col0" >2024-07-15</td>
#       <td id="T_3738b_row0_col1" class="data row0 col1" >53396477</td>
#       <td id="T_3738b_row0_col2" class="data row0 col2" >J.D._Vance</td>
#       <td id="T_3738b_row0_col3" class="data row0 col3" >3397556</td>
#     </tr>
#     <tr>
#       <td id="T_3738b_row1_col0" class="data row1 col0" >2024-12-25</td>
#       <td id="T_3738b_row1_col1" class="data row1 col1" >569</td>
#       <td id="T_3738b_row1_col2" class="data row1 col2" >Anthropology</td>
#       <td id="T_3738b_row1_col3" class="data row1 col3" >3253747</td>
#     </tr>
#     <tr>
#       <td id="T_3738b_row2_col0" class="data row2 col0" >2024-08-06</td>
#       <td id="T_3738b_row2_col1" class="data row2 col1" >2216593</td>
#       <td id="T_3738b_row2_col2" class="data row2 col2" >Gwen_Walz</td>
#       <td id="T_3738b_row2_col3" class="data row2 col3" >2393644</td>
#     </tr>
#     <tr>
#       <td id="T_3738b_row3_col0" class="data row3 col0" >2024-11-13</td>
#       <td id="T_3738b_row3_col1" class="data row3 col1" >34076202</td>
#       <td id="T_3738b_row3_col2" class="data row3 col2" >Hegseth</td>
#       <td id="T_3738b_row3_col3" class="data row3 col3" >2146555</td>
#     </tr>
#     <tr>
#       <td id="T_3738b_row4_col0" class="data row4 col0" >2024-07-16</td>
#       <td id="T_3738b_row4_col1" class="data row4 col1" >53396477</td>
#       <td id="T_3738b_row4_col2" class="data row4 col2" >J.D._Vance</td>
#       <td id="T_3738b_row4_col3" class="data row4 col3" >2071310</td>
#     </tr>
#     <tr>
#       <td id="T_3738b_row5_col0" class="data row5 col0" >2024-11-06</td>
#       <td id="T_3738b_row5_col1" class="data row5 col1" >48410011</td>
#       <td id="T_3738b_row5_col2" class="data row5 col2" >2020_U.S._presidential_election</td>
#       <td id="T_3738b_row5_col3" class="data row5 col3" >1848918</td>
#     </tr>
#     <tr>
#       <td id="T_3738b_row6_col0" class="data row6 col0" >2024-11-22</td>
#       <td id="T_3738b_row6_col1" class="data row6 col1" >4550623</td>
#       <td id="T_3738b_row6_col2" class="data row6 col2" >Pam_Bondi</td>
#       <td id="T_3738b_row6_col3" class="data row6 col3" >1439397</td>
#     </tr>
#     <tr>
#       <td id="T_3738b_row7_col0" class="data row7 col0" >2024-02-24</td>
#       <td id="T_3738b_row7_col1" class="data row7 col1" >15580374</td>
#       <td id="T_3738b_row7_col2" class="data row7 col2" >Google_Chrome</td>
#       <td id="T_3738b_row7_col3" class="data row7 col3" >1430379</td>
#     </tr>
#     <tr>
#       <td id="T_3738b_row8_col0" class="data row8 col0" >2024-11-16</td>
#       <td id="T_3738b_row8_col1" class="data row8 col1" >51021695</td>
#       <td id="T_3738b_row8_col2" class="data row8 col2" >Jake_Paul</td>
#       <td id="T_3738b_row8_col3" class="data row8 col3" >1420154</td>
#     </tr>
#     <tr>
#       <td id="T_3738b_row9_col0" class="data row9 col0" >2024-02-06</td>
#       <td id="T_3738b_row9_col1" class="data row9 col1" >682527</td>
#       <td id="T_3738b_row9_col2" class="data row9 col2" >Toby_Keith</td>
#       <td id="T_3738b_row9_col3" class="data row9 col3" >1403258</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <h3>Set dates to datetime objects for plotting

# %%
df['date'] = pd.to_datetime(df['date'])

# %% [markdown]
# <h3>Get top 10 most viewed pages per day

# %%
df_sorted = df.sort_values(['date', 'view_count'], ascending=[True, False])
df_top50 = df_sorted.groupby('date', group_keys=False).head(50)

# %% [markdown]
# <h3>Plot data

# %%
fig = px.scatter(
    df_top50,
    x='date',
    y='view_count',
    hover_data=['search_key', 'view_count'],
    size_max=20
)

fig.show()

# %%
import sqlite3

# %% [markdown]
# <h3>Get search keys labeled political, as list

# %%
conn = sqlite3.connect('raw_data.db')

sql_query = "SELECT * FROM searchkeys"
keys_df = pd.read_sql_query(sql_query, conn)

# %%
keys_df = keys_df[keys_df['nature'] == 'political']
keys_list = keys_df['search_key'].tolist()

# %% [markdown]
# <h3>Filter out rows with non-political search keys

# %%
df_political = df_top50[df_top50['search_key'].isin(keys_list)]
df_political.head(10).style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c2695">
#   <thead>
#     <tr>
#       <th id="T_c2695_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_c2695_level0_col1" class="col_heading level0 col1" >search_id</th>
#       <th id="T_c2695_level0_col2" class="col_heading level0 col2" >search_key</th>
#       <th id="T_c2695_level0_col3" class="col_heading level0 col3" >view_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c2695_row0_col0" class="data row0 col0" >2024-01-01 00:00:00</td>
#       <td id="T_c2695_row0_col1" class="data row0 col1" >58925</td>
#       <td id="T_c2695_row0_col2" class="data row0 col2" >Margrethe_II</td>
#       <td id="T_c2695_row0_col3" class="data row0 col3" >48584</td>
#     </tr>
#     <tr>
#       <td id="T_c2695_row1_col0" class="data row1 col0" >2024-01-01 00:00:00</td>
#       <td id="T_c2695_row1_col1" class="data row1 col1" >60806927</td>
#       <td id="T_c2695_row1_col2" class="data row1 col2" >Bo_Nix</td>
#       <td id="T_c2695_row1_col3" class="data row1 col3" >47330</td>
#     </tr>
#     <tr>
#       <td id="T_c2695_row2_col0" class="data row2 col0" >2024-01-02 00:00:00</td>
#       <td id="T_c2695_row2_col1" class="data row2 col1" >6253522</td>
#       <td id="T_c2695_row2_col2" class="data row2 col2" >Jeffrey_Epstein</td>
#       <td id="T_c2695_row2_col3" class="data row2 col3" >59496</td>
#     </tr>
#     <tr>
#       <td id="T_c2695_row3_col0" class="data row3 col0" >2024-01-02 00:00:00</td>
#       <td id="T_c2695_row3_col1" class="data row3 col1" >50305655</td>
#       <td id="T_c2695_row3_col2" class="data row3 col2" >Lee_Jae-myung</td>
#       <td id="T_c2695_row3_col3" class="data row3 col3" >42875</td>
#     </tr>
#     <tr>
#       <td id="T_c2695_row4_col0" class="data row4 col0" >2024-01-02 00:00:00</td>
#       <td id="T_c2695_row4_col1" class="data row4 col1" >149709</td>
#       <td id="T_c2695_row4_col2" class="data row4 col2" >Willie_Nelson</td>
#       <td id="T_c2695_row4_col3" class="data row4 col3" >42169</td>
#     </tr>
#     <tr>
#       <td id="T_c2695_row5_col0" class="data row5 col0" >2024-01-02 00:00:00</td>
#       <td id="T_c2695_row5_col1" class="data row5 col1" >40580014</td>
#       <td id="T_c2695_row5_col2" class="data row5 col2" >Molly_McGrath</td>
#       <td id="T_c2695_row5_col3" class="data row5 col3" >33102</td>
#     </tr>
#     <tr>
#       <td id="T_c2695_row6_col0" class="data row6 col0" >2024-01-03 00:00:00</td>
#       <td id="T_c2695_row6_col1" class="data row6 col1" >6253522</td>
#       <td id="T_c2695_row6_col2" class="data row6 col2" >Jeffrey_Epstein</td>
#       <td id="T_c2695_row6_col3" class="data row6 col3" >113898</td>
#     </tr>
#     <tr>
#       <td id="T_c2695_row7_col0" class="data row7 col0" >2024-01-03 00:00:00</td>
#       <td id="T_c2695_row7_col1" class="data row7 col1" >12153654</td>
#       <td id="T_c2695_row7_col2" class="data row7 col2" >Elizabeth_II</td>
#       <td id="T_c2695_row7_col3" class="data row7 col3" >26404</td>
#     </tr>
#     <tr>
#       <td id="T_c2695_row8_col0" class="data row8 col0" >2024-01-03 00:00:00</td>
#       <td id="T_c2695_row8_col1" class="data row8 col1" >8709554</td>
#       <td id="T_c2695_row8_col2" class="data row8 col2" >Nikki_Haley</td>
#       <td id="T_c2695_row8_col3" class="data row8 col3" >24590</td>
#     </tr>
#     <tr>
#       <td id="T_c2695_row9_col0" class="data row9 col0" >2024-01-03 00:00:00</td>
#       <td id="T_c2695_row9_col1" class="data row9 col1" >41703969</td>
#       <td id="T_c2695_row9_col2" class="data row9 col2" >Elise_Stefanik</td>
#       <td id="T_c2695_row9_col3" class="data row9 col3" >23947</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_political_sorted = df_political.sort_values(['date', 'view_count'], ascending=[True, False])
df_top_political = df_political_sorted.groupby('date', group_keys=False).head(50)

# %% [markdown]
# <h3>Plot data

# %%
fig = px.scatter(
    df_top_political,
    x='date',
    y='view_count',
    hover_data=['search_key', 'view_count'],
    size_max=20
)

fig.show()

# %%
df_political_sorted_top = df_political.sort_values(['view_count'], ascending=[False])
df_political_sorted_top.head(10).style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_7efe4">
#   <thead>
#     <tr>
#       <th id="T_7efe4_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_7efe4_level0_col1" class="col_heading level0 col1" >search_id</th>
#       <th id="T_7efe4_level0_col2" class="col_heading level0 col2" >search_key</th>
#       <th id="T_7efe4_level0_col3" class="col_heading level0 col3" >view_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7efe4_row0_col0" class="data row0 col0" >2024-07-15 00:00:00</td>
#       <td id="T_7efe4_row0_col1" class="data row0 col1" >53396477</td>
#       <td id="T_7efe4_row0_col2" class="data row0 col2" >J.D._Vance</td>
#       <td id="T_7efe4_row0_col3" class="data row0 col3" >3397556</td>
#     </tr>
#     <tr>
#       <td id="T_7efe4_row1_col0" class="data row1 col0" >2024-08-06 00:00:00</td>
#       <td id="T_7efe4_row1_col1" class="data row1 col1" >2216593</td>
#       <td id="T_7efe4_row1_col2" class="data row1 col2" >Gwen_Walz</td>
#       <td id="T_7efe4_row1_col3" class="data row1 col3" >2393644</td>
#     </tr>
#     <tr>
#       <td id="T_7efe4_row2_col0" class="data row2 col0" >2024-11-13 00:00:00</td>
#       <td id="T_7efe4_row2_col1" class="data row2 col1" >34076202</td>
#       <td id="T_7efe4_row2_col2" class="data row2 col2" >Hegseth</td>
#       <td id="T_7efe4_row2_col3" class="data row2 col3" >2146555</td>
#     </tr>
#     <tr>
#       <td id="T_7efe4_row3_col0" class="data row3 col0" >2024-07-16 00:00:00</td>
#       <td id="T_7efe4_row3_col1" class="data row3 col1" >53396477</td>
#       <td id="T_7efe4_row3_col2" class="data row3 col2" >J.D._Vance</td>
#       <td id="T_7efe4_row3_col3" class="data row3 col3" >2071310</td>
#     </tr>
#     <tr>
#       <td id="T_7efe4_row4_col0" class="data row4 col0" >2024-11-06 00:00:00</td>
#       <td id="T_7efe4_row4_col1" class="data row4 col1" >48410011</td>
#       <td id="T_7efe4_row4_col2" class="data row4 col2" >2020_U.S._presidential_election</td>
#       <td id="T_7efe4_row4_col3" class="data row4 col3" >1848918</td>
#     </tr>
#     <tr>
#       <td id="T_7efe4_row5_col0" class="data row5 col0" >2024-11-22 00:00:00</td>
#       <td id="T_7efe4_row5_col1" class="data row5 col1" >4550623</td>
#       <td id="T_7efe4_row5_col2" class="data row5 col2" >Pam_Bondi</td>
#       <td id="T_7efe4_row5_col3" class="data row5 col3" >1439397</td>
#     </tr>
#     <tr>
#       <td id="T_7efe4_row6_col0" class="data row6 col0" >2024-07-22 00:00:00</td>
#       <td id="T_7efe4_row6_col1" class="data row6 col1" >3120522</td>
#       <td id="T_7efe4_row6_col2" class="data row6 col2" >Kamala_Harris</td>
#       <td id="T_7efe4_row6_col3" class="data row6 col3" >1231561</td>
#     </tr>
#     <tr>
#       <td id="T_7efe4_row7_col0" class="data row7 col0" >2024-07-15 00:00:00</td>
#       <td id="T_7efe4_row7_col1" class="data row7 col1" >77361269</td>
#       <td id="T_7efe4_row7_col2" class="data row7 col2" >Usha_Chilukuri_Vance</td>
#       <td id="T_7efe4_row7_col3" class="data row7 col3" >1225450</td>
#     </tr>
#     <tr>
#       <td id="T_7efe4_row8_col0" class="data row8 col0" >2024-11-06 00:00:00</td>
#       <td id="T_7efe4_row8_col1" class="data row8 col1" >59568546</td>
#       <td id="T_7efe4_row8_col2" class="data row8 col2" >2024_U.S._presidential_election</td>
#       <td id="T_7efe4_row8_col3" class="data row8 col3" >1160814</td>
#     </tr>
#     <tr>
#       <td id="T_7efe4_row9_col0" class="data row9 col0" >2024-08-07 00:00:00</td>
#       <td id="T_7efe4_row9_col1" class="data row9 col1" >2216593</td>
#       <td id="T_7efe4_row9_col2" class="data row9 col2" >Tim_Waltz</td>
#       <td id="T_7efe4_row9_col3" class="data row9 col3" >1036054</td>
#     </tr>
#   </tbody>
# </table>

# %%
top_500 = df_political_sorted_top.head(500)
top_500_dated = top_500.sort_values(['date', 'view_count'], ascending=[True, False])

# %%
fig = px.scatter(
    top_500_dated,
    x='date',
    y='view_count',
    hover_data=['search_key', 'view_count'],
    size_max=20
)

fig.show()

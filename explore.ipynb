# %% [markdown]
# <h2>Initial Exploration of Wikipedia Pageview Data<h2>

# %%
import pandas as pd
import sqlite3
import plotly.express as px

# %%
conn = sqlite3.connect('raw_data.db')

sql_query = "SELECT * FROM pageviews"
df = pd.read_sql_query(sql_query, conn)

# %% [markdown]
# <h3>Filter out irrelevant search_keys and dates outside of 2024

# %%
df = df[~df['search_key'].isin(['Cookie_(informatique)', 'Main_Page'])]
df = df[df['date'].str[:4] == '2024']

# %% [markdown]
# <h3>Beginning of data (Jan 1, 2024)

# %%
df.head(10).style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_ea436">
#   <thead>
#     <tr>
#       <th id="T_ea436_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_ea436_level0_col1" class="col_heading level0 col1" >search_id</th>
#       <th id="T_ea436_level0_col2" class="col_heading level0 col2" >search_key</th>
#       <th id="T_ea436_level0_col3" class="col_heading level0 col3" >view_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ea436_row0_col0" class="data row0 col0" >2024-01-01</td>
#       <td id="T_ea436_row0_col1" class="data row0 col1" >18713</td>
#       <td id="T_ea436_row0_col2" class="data row0 col2" >Lynyrd_Skynyrd</td>
#       <td id="T_ea436_row0_col3" class="data row0 col3" >374849</td>
#     </tr>
#     <tr>
#       <td id="T_ea436_row1_col0" class="data row1 col0" >2024-01-01</td>
#       <td id="T_ea436_row1_col1" class="data row1 col1" >36792343</td>
#       <td id="T_ea436_row1_col2" class="data row1 col2" >Elle_King</td>
#       <td id="T_ea436_row1_col3" class="data row1 col3" >307689</td>
#     </tr>
#     <tr>
#       <td id="T_ea436_row2_col0" class="data row2 col0" >2024-01-01</td>
#       <td id="T_ea436_row2_col1" class="data row2 col1" >100691</td>
#       <td id="T_ea436_row2_col2" class="data row2 col2" >Paul_Anka</td>
#       <td id="T_ea436_row2_col3" class="data row2 col3" >269259</td>
#     </tr>
#     <tr>
#       <td id="T_ea436_row3_col0" class="data row3 col0" >2024-01-01</td>
#       <td id="T_ea436_row3_col1" class="data row3 col1" >80903</td>
#       <td id="T_ea436_row3_col2" class="data row3 col2" >Billie_Joe_Armstrong</td>
#       <td id="T_ea436_row3_col3" class="data row3 col3" >191331</td>
#     </tr>
#     <tr>
#       <td id="T_ea436_row4_col0" class="data row4 col0" >2024-01-01</td>
#       <td id="T_ea436_row4_col1" class="data row4 col1" >52726</td>
#       <td id="T_ea436_row4_col2" class="data row4 col2" >Green_Day</td>
#       <td id="T_ea436_row4_col3" class="data row4 col3" >170677</td>
#     </tr>
#     <tr>
#       <td id="T_ea436_row5_col0" class="data row5 col0" >2024-01-01</td>
#       <td id="T_ea436_row5_col1" class="data row5 col1" >54162498</td>
#       <td id="T_ea436_row5_col2" class="data row5 col2" >Gypsy_Rose_Blanchard</td>
#       <td id="T_ea436_row5_col3" class="data row5 col3" >164705</td>
#     </tr>
#     <tr>
#       <td id="T_ea436_row6_col0" class="data row6 col0" >2024-01-01</td>
#       <td id="T_ea436_row6_col1" class="data row6 col1" >170459</td>
#       <td id="T_ea436_row6_col2" class="data row6 col2" >LL_Cool_J</td>
#       <td id="T_ea436_row6_col3" class="data row6 col3" >162843</td>
#     </tr>
#     <tr>
#       <td id="T_ea436_row7_col0" class="data row7 col0" >2024-01-01</td>
#       <td id="T_ea436_row7_col1" class="data row7 col1" >218238</td>
#       <td id="T_ea436_row7_col2" class="data row7 col2" >Rob_Schneider</td>
#       <td id="T_ea436_row7_col3" class="data row7 col3" >150123</td>
#     </tr>
#     <tr>
#       <td id="T_ea436_row8_col0" class="data row8 col0" >2024-01-01</td>
#       <td id="T_ea436_row8_col1" class="data row8 col1" >1473365</td>
#       <td id="T_ea436_row8_col2" class="data row8 col2" >Johnny_Van_Zant</td>
#       <td id="T_ea436_row8_col3" class="data row8 col3" >140385</td>
#     </tr>
#     <tr>
#       <td id="T_ea436_row9_col0" class="data row9 col0" >2024-01-01</td>
#       <td id="T_ea436_row9_col1" class="data row9 col1" >12342282</td>
#       <td id="T_ea436_row9_col2" class="data row9 col2" >List_of_Lynyrd_Skynyrd_members</td>
#       <td id="T_ea436_row9_col3" class="data row9 col3" >132688</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <h3>Pages with most views in a single day in 2024

# %%
df.sort_values(by='view_count', ascending=False).head(10).style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_a9d51">
#   <thead>
#     <tr>
#       <th id="T_a9d51_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_a9d51_level0_col1" class="col_heading level0 col1" >search_id</th>
#       <th id="T_a9d51_level0_col2" class="col_heading level0 col2" >search_key</th>
#       <th id="T_a9d51_level0_col3" class="col_heading level0 col3" >view_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a9d51_row0_col0" class="data row0 col0" >2024-07-15</td>
#       <td id="T_a9d51_row0_col1" class="data row0 col1" >53396477</td>
#       <td id="T_a9d51_row0_col2" class="data row0 col2" >J.D._Vance</td>
#       <td id="T_a9d51_row0_col3" class="data row0 col3" >3397556</td>
#     </tr>
#     <tr>
#       <td id="T_a9d51_row1_col0" class="data row1 col0" >2024-12-25</td>
#       <td id="T_a9d51_row1_col1" class="data row1 col1" >569</td>
#       <td id="T_a9d51_row1_col2" class="data row1 col2" >Anthropology</td>
#       <td id="T_a9d51_row1_col3" class="data row1 col3" >3253747</td>
#     </tr>
#     <tr>
#       <td id="T_a9d51_row2_col0" class="data row2 col0" >2024-08-06</td>
#       <td id="T_a9d51_row2_col1" class="data row2 col1" >2216593</td>
#       <td id="T_a9d51_row2_col2" class="data row2 col2" >Gwen_Walz</td>
#       <td id="T_a9d51_row2_col3" class="data row2 col3" >2393644</td>
#     </tr>
#     <tr>
#       <td id="T_a9d51_row3_col0" class="data row3 col0" >2024-11-13</td>
#       <td id="T_a9d51_row3_col1" class="data row3 col1" >34076202</td>
#       <td id="T_a9d51_row3_col2" class="data row3 col2" >Hegseth</td>
#       <td id="T_a9d51_row3_col3" class="data row3 col3" >2146555</td>
#     </tr>
#     <tr>
#       <td id="T_a9d51_row4_col0" class="data row4 col0" >2024-07-16</td>
#       <td id="T_a9d51_row4_col1" class="data row4 col1" >53396477</td>
#       <td id="T_a9d51_row4_col2" class="data row4 col2" >J.D._Vance</td>
#       <td id="T_a9d51_row4_col3" class="data row4 col3" >2071310</td>
#     </tr>
#     <tr>
#       <td id="T_a9d51_row5_col0" class="data row5 col0" >2024-11-06</td>
#       <td id="T_a9d51_row5_col1" class="data row5 col1" >48410011</td>
#       <td id="T_a9d51_row5_col2" class="data row5 col2" >2020_U.S._presidential_election</td>
#       <td id="T_a9d51_row5_col3" class="data row5 col3" >1848918</td>
#     </tr>
#     <tr>
#       <td id="T_a9d51_row6_col0" class="data row6 col0" >2024-11-22</td>
#       <td id="T_a9d51_row6_col1" class="data row6 col1" >4550623</td>
#       <td id="T_a9d51_row6_col2" class="data row6 col2" >Pam_Bondi</td>
#       <td id="T_a9d51_row6_col3" class="data row6 col3" >1439397</td>
#     </tr>
#     <tr>
#       <td id="T_a9d51_row7_col0" class="data row7 col0" >2024-02-24</td>
#       <td id="T_a9d51_row7_col1" class="data row7 col1" >15580374</td>
#       <td id="T_a9d51_row7_col2" class="data row7 col2" >Google_Chrome</td>
#       <td id="T_a9d51_row7_col3" class="data row7 col3" >1430379</td>
#     </tr>
#     <tr>
#       <td id="T_a9d51_row8_col0" class="data row8 col0" >2024-11-16</td>
#       <td id="T_a9d51_row8_col1" class="data row8 col1" >51021695</td>
#       <td id="T_a9d51_row8_col2" class="data row8 col2" >Jake_Paul</td>
#       <td id="T_a9d51_row8_col3" class="data row8 col3" >1420154</td>
#     </tr>
#     <tr>
#       <td id="T_a9d51_row9_col0" class="data row9 col0" >2024-02-06</td>
#       <td id="T_a9d51_row9_col1" class="data row9 col1" >682527</td>
#       <td id="T_a9d51_row9_col2" class="data row9 col2" >Toby_Keith</td>
#       <td id="T_a9d51_row9_col3" class="data row9 col3" >1403258</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <h3>Set dates to datetime objects for plotting

# %%
df['date'] = pd.to_datetime(df['date'])

# %% [markdown]
# <h3>Get top 10 most viewed pages per day

# %%
df_sorted = df.sort_values(['date', 'view_count'], ascending=[True, False])
df_top10 = df_sorted.groupby('date', group_keys=False).head(10)

# %% [markdown]
# <h3>Plot data

# %%
fig = px.scatter(
    df_top10,
    x='date',
    y='view_count',
    hover_data=['search_key', 'view_count'],
    size_max=20
)

fig.show()

# %%
import sqlite3
import db

# %%
# db.init_searchkeys()

# %%
from google import genai

client = genai.Client()

def machinedotlearn(search_key: str) -> str:
    contents = f"""
    Classify the political nature of the following Wikipeda page title: '{search_key}'. 
    Respond strictly with one of the following options: political, non-political, or not-sure.
    Titles marked 'political' should include: Political figures and issues, voting logistics,
    and general political topics (e.g. elections, climate change, abortion, etc...)"""
    response = client.models.generate_content(
        model="gemini-2.5-flash", 
        contents=contents
    )
    return response.text

def insert_nature(search_key: str) -> None:
    nature = machinedotlearn(search_key)
    print(f'{search_key}: {nature}')
    db.insert_searchkey_nature(search_key, nature)

# %%
df_unique = df['search_key'].unique()
df_unique[:10]
# Out:
# array(['Lynyrd_Skynyrd', 'Elle_King', 'Paul_Anka', 'Billie_Joe_Armstrong',
#        'Green_Day', 'Gypsy_Rose_Blanchard', 'LL_Cool_J', 'Rob_Schneider',
#        'Johnny_Van_Zant', 'List_of_Lynyrd_Skynyrd_members'], dtype=object)

# %%
for search_key in df_unique[10:]:
    insert_nature(search_key)
# Out:
# Jared_Leto: non-political
# Saltburn_(film): non-political
# Lainey_Wilson: non-political
# Ronnie_Van_Zant: non-political
# Anderson_Cooper: political
# JellyRoll: non-political
# Andy_Cohen: non-political
# Rita_Ora: non-political
# Thirty_Seconds_to_Mars: non-political
# Rickey_Medlocke: non-political
# Ivy_Queen: non-political
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[31], line 3
#       1 # for title in df_unique:
#       2 for search_key in df_unique[10:]:
# ----> 3     insert_nature(search_key)
#
# Cell In[28], line 18, in insert_nature(search_key)
#      17 def insert_nature(search_key: str) -> None:
# ---> 18     nature = machinedotlearn(search_key)
#      19     print(f'{search_key}: {nature}')
#      20     db.insert_searchkey_nature(search_key, nature)
#
# Cell In[28], line 11, in machinedotlearn(search_key)
#       5 def machinedotlearn(search_key: str) -> str:
#       6     contents = f"""
#       7     Classify the political nature of the following Wikipeda page title: '{search_key}'.
#       8     Respond strictly with one of the following options: political, non-political, or not-sure.
#       9     Titles marked 'political' should include: Political figures and issues, voting logistics,
#      10     and general political topics (e.g. elections, climate change, abortion, etc...)"""
# ---> 11     response = client.models.generate_content(
#      12         model="gemini-2.5-flash",
#      13         contents=contents
#      14     )
#      15     return response.text
#
# File c:\Users\diann\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\models.py:6498, in Models.generate_content(self, model, contents, config)
#    6496 while remaining_remote_calls_afc > 0:
#    6497   i += 1
# -> 6498   response = self._generate_content(
#    6499       model=model, contents=contents, config=parsed_config
#    6500   )
#    6502   function_map = _extra_utils.get_function_map(parsed_config)
#    6503   if not function_map:
#
# File c:\Users\diann\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\models.py:5310, in Models._generate_content(self, model, contents, config)
#    5307 request_dict = _common.convert_to_dict(request_dict)
#    5308 request_dict = _common.encode_unserializable_types(request_dict)
# -> 5310 response = self._api_client.request(
#    5311     'post', path, request_dict, http_options
#    5312 )
#    5314 if config is not None and getattr(
#    5315     config, 'should_return_http_response', None
#    5316 ):
#    5317   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File c:\Users\diann\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\_api_client.py:1291, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1281 def request(
#    1282     self,
#    1283     http_method: str,
#    (...)
#    1286     http_options: Optional[HttpOptionsOrDict] = None,
#    1287 ) -> SdkHttpResponse:
#    1288   http_request = self._build_request(
#    1289       http_method, path, request_dict, http_options
#    1290   )
# -> 1291   response = self._request(http_request, http_options, stream=False)
#    1292   response_body = (
#    1293       response.response_stream[0] if response.response_stream else ''
#    1294   )
#    1295   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File c:\Users\diann\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\_api_client.py:1127, in BaseApiClient._request(self, http_request, http_options, stream)
#    1124     retry = tenacity.Retrying(**retry_kwargs)
#    1125     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1127 return self._retry(self._request_once, http_request, stream)
#
# File c:\Users\diann\AppData\Local\Programs\Python\Python313\Lib\site-packages\tenacity\__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File c:\Users\diann\AppData\Local\Programs\Python\Python313\Lib\site-packages\tenacity\__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File c:\Users\diann\AppData\Local\Programs\Python\Python313\Lib\site-packages\tenacity\__init__.py:418, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     416 retry_exc = self.retry_error_cls(fut)
#     417 if self.reraise:
# --> 418     raise retry_exc.reraise()
#     419 raise retry_exc from fut.exception()
#
# File c:\Users\diann\AppData\Local\Programs\Python\Python313\Lib\site-packages\tenacity\__init__.py:185, in RetryError.reraise(self)
#     183 def reraise(self) -> t.NoReturn:
#     184     if self.last_attempt.failed:
# --> 185         raise self.last_attempt.result()
#     186     raise self
#
# File c:\Users\diann\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\diann\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\diann\AppData\Local\Programs\Python\Python313\Lib\site-packages\tenacity\__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Users\diann\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\_api_client.py:1104, in BaseApiClient._request_once(self, http_request, stream)
#    1096 else:
#    1097   response = self._httpx_client.request(
#    1098       method=http_request.method,
#    1099       url=http_request.url,
#    (...)
#    1102       timeout=http_request.timeout,
#    1103   )
# -> 1104   errors.APIError.raise_for_response(response)
#    1105   return HttpResponse(
#    1106       response.headers, response if stream else [response.text]
#    1107   )
#
# File c:\Users\diann\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\errors.py:108, in APIError.raise_for_response(cls, response)
#     106 status_code = response.status_code
#     107 if 400 <= status_code < 500:
# --> 108   raise ClientError(status_code, response_json, response)
#     109 elif 500 <= status_code < 600:
#     110   raise ServerError(status_code, response_json, response)
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 10\nPlease retry in 2.706531811s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '2s'}]}}
